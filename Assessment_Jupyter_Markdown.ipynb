# %% [markdown]
# <h1>My Jupyter Notebook on IBM Data Science Experience</h1>

# %% [markdown]
# <b> Thrishna Balakrishnan </b>
# <p> Occupation: Student </p>

# %% [markdown]
# <em>I am interested in data science because I am a graduate in Information sytems. I believe this course will help me to understand Data Science better.</em>

# %% [markdown]
# <h3> The below code displays the name typed by the user </h3>

# %%
def print_name():
    fname = input("Enter your first name:\t")
    try:
     fn = int(fname)
     if(isinstance(fn,int))is True:
       print("Please enter a valid name\t")
    except ValueError:
        lname = input("Enter your last name:\t")
        try:
         ln = int(lname)
         if(isinstance(ln,int))is True:
          print("Please enter a valid name\t")
        except ValueError:
         print("Your name is\t",fname," ",lname)

# %%
print_name()
# Out:
# Enter your first name:	buhuhu
# Enter your last name:	154564
# Please enter a valid name

# %%
print_name()
# Out:
# Enter your first name:	Thrishna
# Enter your last name:	Balakrishnan
# Your name is	 Thrishna   Balakrishnan

# %% [markdown]
# <hr/>

# %%
print_name()
# Out:
# Enter your first name:	145454
# Please enter a valid name

# %% [markdown]
# <h4> What I learned from this excercise </h4>

# %% [markdown]
#   - The input is always fed as String

# %% [markdown]
# - The input must be converted to integer to check if the input is number

# %% [markdown]
# - The above code uses try and except to check if the input is string

# %% [markdown]
# ![puppy.png](attachment:puppy.png)

# %% [markdown]
# [All about puppies](https://dogtime.com/puppies)

# %% [markdown]
# | No|Task|
# |:--|---:|
# |1|Type code|
# |2|Execute|
# |3|Debug if failure|
